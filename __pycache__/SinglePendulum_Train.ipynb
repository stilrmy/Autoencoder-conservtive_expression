# %%
import numpy as np
import sys 

from autoencoder_v3 import loading_coef,encoder_forward,encoder_derivative
from sympy import symbols, simplify, derive_by_array
from scipy.integrate import solve_ivp
from sympy.physics.mechanics import *
from sympy import *
from numpy import sin, cos, tan, cosh, tanh, sinh
from torch.autograd import Variable
import sympy
import torch
import sys
import HLsearch as HL
import example_pendulum
import time
import matplotlib.pyplot as plt
import os
# Out:
# 4.509234430617567e-19

# %%
device = 'cuda:3'
data = example_pendulum.get_pendulum_data(40)

# %%
np.random.seed(7)
#torch.manual_seed(7)
torch.cuda.manual_seed_all(7)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
num_sample = 100
training = True
save = False
noiselevel = 2e-2
params={}
environment = 'SERVER'
if environment == 'LAPTOP':
    file_route = R'C:\Users\87106\OneDrive\sindy\progress\AE'
elif environment == 'DESTOP':
    file_route = R'E:\OneDrive\sindy\progress\AE'
elif environment == 'SERVER':
    file_route = R'/mnt/ssd1/stilrmy/Autoencoder-conservtive_expression/progress'
if environment == 'LAPTOP':
    params['root_dir'] =R'C:\Users\87106\OneDrive\sindy\progress'
elif environment == 'DESTOP':
    params['root_dir'] = R'E:\OneDrive\sindy\progress'
elif environment == 'SERVER':
    params['root_dir'] = R'/mnt/ssd1/stilrmy/Autoencoder-conservtive_expression/progress'
params['if_save'] = False
params['save_date'] = '4-4'
params['save_ver'] = '1'
PATH = os.path.join(params['root_dir'], params['save_date'],'latent_detect',params['save_ver'])

load_date = '2023-04-26'
load_ver = '1'
widths = [1024,512,128]

params['ver'] = 1
params['date'] = '2023-04-26'
params['widths'] = widths
params['activation'] = 'sigmoid'
params['batch_size'] = 500
params['learning_rate'] = 1e-5
params['learning_rate_stage2'] = 1e-5
params['threshold'] = 0.4
params['num_epochs'] = 100000
params['sample_frequency'] = 100
params = loading_coef(params,load_date,load_ver,file_route,device)
image = torch.from_numpy(data['x']).to(torch.float32).to(device)
image_t = torch.from_numpy(data['dx']).to(torch.float32).to(device)
image_tt = torch.from_numpy(data['ddx']).to(torch.float32).to(device)
x = encoder_forward(image,params)
#x = x.clone().detach().requires_grad_(True)
x = x.cpu().detach().numpy()
dx,ddx = encoder_derivative(image,image_t,image_tt,params)
#dx = dx.clone().detach().requires_grad_(True) 
#ddx = ddx.clone().detach().requires_grad_(True)  
dx = dx.cpu().detach().numpy()
ddx = ddx.cpu().detach().numpy()
X = []
Xdot = []
loss_history = []
t = len(x)
# Out:
# loading params
# torch.Size([2601, 1024])
# torch.Size([1024, 512])
# torch.Size([512, 128])
# torch.Size([128, 1])
# torch.Size([1024])
# torch.Size([512])
# torch.Size([128])
# torch.Size([1])
# torch.Size([1, 128])
# torch.Size([128, 512])
# torch.Size([512, 1024])
# torch.Size([1024, 2601])
# torch.Size([128])
# torch.Size([512])
# torch.Size([1024])
# torch.Size([2601])

# %%
#adding noise
#not modified yet
"""
mu, sigma = 0, noiselevel
noise = np.random.normal(mu, sigma, X.shape[0])
for i in range(X.shape[1]):
    X[:,i] = X[:,i]+noise
    Xdot[:,i] = Xdot[:,i]+noise
"""
# Out:
# '\nmu, sigma = 0, noiselevel\nnoise = np.random.normal(mu, sigma, X.shape[0])\nfor i in range(X.shape[1]):\n    X[:,i] = X[:,i]+noise\n    Xdot[:,i] = Xdot[:,i]+noise\n'

# %%
states_dim = 2
states = ()
states_dot = ()
for i in range(states_dim):
    if(i<states_dim//2):
        states = states + (symbols('x{}'.format(i)),)
        states_dot = states_dot + (symbols('x{}_t'.format(i)),)
    else:
        states = states + (symbols('x{}_t'.format(i-states_dim//2)),)
        states_dot = states_dot + (symbols('x{}_tt'.format(i-states_dim//2)),)
print('states are:',states)
print('states derivatives are: ', states_dot)
#Turn from sympy to str
states_sym = states
states_dot_sym = states_dot
states = list(str(descr) for descr in states)
states_dot = list(str(descr) for descr in states_dot)
# Out:
# states are: (x0, x0_t)
# states derivatives are:  (x0_t, x0_tt)

# %%
#build function expression for the library in str
expr= HL.buildFunctionExpressions(2,states_dim,states,use_sine=True)
#expr=['x0', 'x0_t', 'sin(x0)', 'cos(x0)', 'x0**2', 'x0*x0_t', 
#'x0_t**2', 'x0*sin(x0)', 'x0_t*sin(x0)', 'sin(x0)**2', 
#'x0*cos(x0)', 'x0_t*cos(x0)', 'sin(x0)*cos(x0)', 'cos(x0)**2']
#expr=['cos(x0)','x0_t**2']
"a list of candidate function"
print(expr)
coef = torch.ones(len(expr), device=device).data.uniform_(-10,10)
coef = Variable(coef,requires_grad=True)
# Out:
# ['x0', 'x0_t', 'sin(x0)', 'cos(x0)', 'x0**2', 'x0*x0_t', 'x0_t**2', 'x0*sin(x0)', 'x0_t*sin(x0)', 'sin(x0)**2', 'x0*cos(x0)', 'x0_t*cos(x0)', 'sin(x0)*cos(x0)', 'cos(x0)**2']

# %%
#TBD
#time derivative of the expressions
expr_dot = ['x0_t','x0_tt','x0_t*cos(x0)','-x0_t*cos(x0)','2*x0_t*x0',
           'x0_t**2+x0*x0_tt','2*x0_t*x0_tt','x0_t*sin(x0)+x0*x0_t*cos(x0)',
           'x0_tt*sin(x0)+cos(x0)*x0_t**2','2*x0_t*sin(x0)*cos(x0)',
           'x0_t*cos(x0)-x0*x0_t*sin(x0)','x0_tt*cos(x0)-sin(x0)*x0_t**2',
           'x0_t*cos(x0)**2-x0_t*sin(x0)**2','-2*x0_t*sin(x0)*cos(x0)']

# %%
#load the latent variables and calculate the expressions
expr_val = torch.ones(len(expr),t,device=device)
expr_dot_val = torch.ones(len(expr),t,device=device)
locals()[states[0]] = x
locals()[states[1]] = dx
locals()[states_dot[0]] = dx
locals()[states_dot[1]] = ddx
print(eval(str(expr[2])))
for n in range(len(expr)):
    temp = eval(str(expr[n]))
    temp = torch.tensor(temp,dtype=torch.float32,device=device)
    for i,j in enumerate(temp):
        expr_val[n,i] = j
    temp = eval(str(expr_dot[n]))
    temp = torch.tensor(temp,dtype=torch.float32,device=device)
    for i,j in enumerate(temp):
        expr_dot_val[n,i] = j
# Out:
# [[-0.41111872]
#  [-0.41111526]
#  [-0.41111177]
#  ...
#  [-0.41090226]
#  [-0.41114438]
#  [-0.4113556 ]]

# %%
def training_loop(coef,t,expr_val,expr_dot_val,params):
    coef.requires_grad_(True)
    loss_list = []
    training_set_size = t
    batch_size = params['batch_size']
    opt = torch.optim.Adam([coef], lr=params['learning_rate'])
    for i in range(training_set_size//batch_size):
        expr_dot_val_batch = expr_dot_val[:,i*batch_size:(i+1)*batch_size]
        loss = torch.abs(torch.sum(torch.matmul(coef,expr_dot_val_batch)))#+0.01*len(expr)+ 0.3*torch.abs(torch.mean(coef))
        opt.zero_grad() 
        loss.backward()
        opt.step()
        loss_list.append(loss.item())
    return coef,torch.tensor(loss_list).mean().item()

# %%
for epoch in range(params['num_epochs']):
    coef, loss = training_loop(coef,t,expr_val,expr_dot_val,params)
    loss_history.append(loss)
    if epoch >= 1500:
        params['learning_rate'] =  params['learning_rate_stage2']
    if epoch % params['sample_frequency'] == 0:
        print("\n")
        print("Epoch: ", epoch)
        print("Average loss : " , loss)
        print("expression:")
        print(HL.generateExpression(coef.cpu().detach().numpy(),expr))
        print("number of candidates: ", len(expr))
    survive_index = ((torch.abs(coef) >= params['threshold']).nonzero(as_tuple=True)[0]).detach().cpu().numpy()
    expr = np.array(expr)[survive_index].tolist()
    coef = coef[survive_index].clone().detach()
    expr_val = expr_val[survive_index,:].clone().detach()
    expr_dot_val = expr_dot_val[survive_index,:].clone().detach()
plt.plot(loss_history)
# Out:
# Epoch:  0
# Average loss :  17.75989532470703
# expression:
# 9.091976*x0 + -0.09945573*x0_t + 8.839097*sin(x0) + 1.8515697*cos(x0) + 3.991969*x0**2 + -5.82526*x0*x0_t + 3.5057788*x0_t**2 + -0.37948102*x0*sin(x0) + 2.6669128*x0_t*sin(x0) + 1.466228*sin(x0)**2 + 8.243231*x0*cos(x0) + 4.414718*x0_t*cos(x0) + 5.074208*sin(x0)*cos(x0) + -1.4165791*cos(x0)**2 +
# number of candidates:  14
#
#
# Epoch:  100
# Average loss :  17.730937957763672
# expression:
# 9.095409*x0 + 8.84253*sin(x0) + 1.8480172*cos(x0) + 3.9884405*x0**2 + -5.800226*x0*x0_t + 3.5136943*x0_t**2 + 2.6920183*x0_t*sin(x0) + 1.4626756*sin(x0)**2 + 8.239798*x0*cos(x0) + 4.389684*x0_t*cos(x0) + 5.0776887*sin(x0)*cos(x0) + -1.4130267*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  200
# Average loss :  17.64659309387207
# expression:
# 9.098843*x0 + 8.8459635*sin(x0) + 1.8444648*cos(x0) + 3.984912*x0**2 + -5.7751923*x0*x0_t + 3.5216098*x0_t**2 + 2.7171237*x0_t*sin(x0) + 1.4591231*sin(x0)**2 + 8.236364*x0*cos(x0) + 4.3646502*x0_t*cos(x0) + 5.0811696*sin(x0)*cos(x0) + -1.4094743*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  300
# Average loss :  17.562240600585938
# expression:
# 9.102276*x0 + 8.849397*sin(x0) + 1.8409123*cos(x0) + 3.9813833*x0**2 + -5.7501583*x0*x0_t + 3.5295253*x0_t**2 + 2.7422292*x0_t*sin(x0) + 1.4555707*sin(x0)**2 + 8.232931*x0*cos(x0) + 4.3396163*x0_t*cos(x0) + 5.0846505*sin(x0)*cos(x0) + -1.4059218*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  400
# Average loss :  17.477901458740234
# expression:
# 9.105709*x0 + 8.85283*sin(x0) + 1.8373599*cos(x0) + 3.9778547*x0**2 + -5.7251244*x0*x0_t + 3.5374408*x0_t**2 + 2.7673347*x0_t*sin(x0) + 1.4520183*sin(x0)**2 + 8.229498*x0*cos(x0) + 4.3145823*x0_t*cos(x0) + 5.0881314*sin(x0)*cos(x0) + -1.4023694*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  500
# Average loss :  17.393543243408203
# expression:
# 9.109142*x0 + 8.856263*sin(x0) + 1.8338075*cos(x0) + 3.9743261*x0**2 + -5.7000904*x0*x0_t + 3.5453563*x0_t**2 + 2.7924402*x0_t*sin(x0) + 1.4484658*sin(x0)**2 + 8.226065*x0*cos(x0) + 4.2895484*x0_t*cos(x0) + 5.0916123*sin(x0)*cos(x0) + -1.398817*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  600
# Average loss :  17.309207916259766
# expression:
# 9.112576*x0 + 8.859696*sin(x0) + 1.830255*cos(x0) + 3.9707975*x0**2 + -5.6750565*x0*x0_t + 3.5532718*x0_t**2 + 2.8175457*x0_t*sin(x0) + 1.4449134*sin(x0)**2 + 8.222631*x0*cos(x0) + 4.2645144*x0_t*cos(x0) + 5.0950933*sin(x0)*cos(x0) + -1.3952645*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  700
# Average loss :  17.224864959716797
# expression:
# 9.116009*x0 + 8.86313*sin(x0) + 1.8267026*cos(x0) + 3.967269*x0**2 + -5.6500225*x0*x0_t + 3.5611873*x0_t**2 + 2.8426511*x0_t*sin(x0) + 1.441361*sin(x0)**2 + 8.219198*x0*cos(x0) + 4.2394805*x0_t*cos(x0) + 5.098574*sin(x0)*cos(x0) + -1.3917121*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  800
# Average loss :  17.14052963256836
# expression:
# 9.119442*x0 + 8.866563*sin(x0) + 1.8231502*cos(x0) + 3.9637403*x0**2 + -5.6249886*x0*x0_t + 3.5691028*x0_t**2 + 2.8677566*x0_t*sin(x0) + 1.4378085*sin(x0)**2 + 8.215765*x0*cos(x0) + 4.2144465*x0_t*cos(x0) + 5.102055*sin(x0)*cos(x0) + -1.3881596*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  900
# Average loss :  17.056167602539062
# expression:
# 9.122875*x0 + 8.869996*sin(x0) + 1.8195977*cos(x0) + 3.9602118*x0**2 + -5.5999546*x0*x0_t + 3.5770183*x0_t**2 + 2.892862*x0_t*sin(x0) + 1.4342561*sin(x0)**2 + 8.212332*x0*cos(x0) + 4.1894126*x0_t*cos(x0) + 5.105536*sin(x0)*cos(x0) + -1.3846072*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1000
# Average loss :  16.971820831298828
# expression:
# 9.126308*x0 + 8.873429*sin(x0) + 1.8160453*cos(x0) + 3.9566832*x0**2 + -5.5749207*x0*x0_t + 3.5849338*x0_t**2 + 2.9179676*x0_t*sin(x0) + 1.4307036*sin(x0)**2 + 8.208899*x0*cos(x0) + 4.1643786*x0_t*cos(x0) + 5.109017*sin(x0)*cos(x0) + -1.3810548*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1100
# Average loss :  16.88747787475586
# expression:
# 9.129742*x0 + 8.876863*sin(x0) + 1.8124928*cos(x0) + 3.9531546*x0**2 + -5.5498867*x0*x0_t + 3.5928493*x0_t**2 + 2.943073*x0_t*sin(x0) + 1.4271512*sin(x0)**2 + 8.205465*x0*cos(x0) + 4.1393447*x0_t*cos(x0) + 5.112498*sin(x0)*cos(x0) + -1.3775023*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1200
# Average loss :  16.80312728881836
# expression:
# 9.133175*x0 + 8.880296*sin(x0) + 1.8089404*cos(x0) + 3.949626*x0**2 + -5.5248528*x0*x0_t + 3.6007648*x0_t**2 + 2.9681785*x0_t*sin(x0) + 1.4235988*sin(x0)**2 + 8.202032*x0*cos(x0) + 4.1143107*x0_t*cos(x0) + 5.1159787*sin(x0)*cos(x0) + -1.3739499*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1300
# Average loss :  16.718793869018555
# expression:
# 9.136608*x0 + 8.883729*sin(x0) + 1.805388*cos(x0) + 3.9460974*x0**2 + -5.499819*x0*x0_t + 3.6086802*x0_t**2 + 2.993284*x0_t*sin(x0) + 1.4200463*sin(x0)**2 + 8.198599*x0*cos(x0) + 4.089277*x0_t*cos(x0) + 5.1194596*sin(x0)*cos(x0) + -1.3703974*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1400
# Average loss :  16.63444709777832
# expression:
# 9.140041*x0 + 8.887162*sin(x0) + 1.8018355*cos(x0) + 3.9425688*x0**2 + -5.474785*x0*x0_t + 3.6165957*x0_t**2 + 3.0183895*x0_t*sin(x0) + 1.4164939*sin(x0)**2 + 8.195166*x0*cos(x0) + 4.064243*x0_t*cos(x0) + 5.1229405*sin(x0)*cos(x0) + -1.366845*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1500
# Average loss :  16.55009651184082
# expression:
# 9.143475*x0 + 8.890595*sin(x0) + 1.7982831*cos(x0) + 3.9390402*x0**2 + -5.449751*x0*x0_t + 3.6245112*x0_t**2 + 3.043495*x0_t*sin(x0) + 1.4129415*sin(x0)**2 + 8.191732*x0*cos(x0) + 4.039209*x0_t*cos(x0) + 5.1264215*sin(x0)*cos(x0) + -1.3632926*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1600
# Average loss :  16.465755462646484
# expression:
# 9.146908*x0 + 8.894029*sin(x0) + 1.7947307*cos(x0) + 3.9355116*x0**2 + -5.424717*x0*x0_t + 3.6324267*x0_t**2 + 3.0686004*x0_t*sin(x0) + 1.409389*sin(x0)**2 + 8.188299*x0*cos(x0) + 4.014175*x0_t*cos(x0) + 5.1299024*sin(x0)*cos(x0) + -1.3597401*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1700
# Average loss :  16.381397247314453
# expression:
# 9.150341*x0 + 8.897462*sin(x0) + 1.7911782*cos(x0) + 3.931983*x0**2 + -5.399683*x0*x0_t + 3.6403422*x0_t**2 + 3.093706*x0_t*sin(x0) + 1.4058366*sin(x0)**2 + 8.184866*x0*cos(x0) + 3.9891002*x0_t*cos(x0) + 5.1333833*sin(x0)*cos(x0) + -1.3561877*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1800
# Average loss :  16.297012329101562
# expression:
# 9.153774*x0 + 8.900895*sin(x0) + 1.7876258*cos(x0) + 3.9284544*x0**2 + -5.374649*x0*x0_t + 3.6482577*x0_t**2 + 3.1188114*x0_t*sin(x0) + 1.4022841*sin(x0)**2 + 8.181433*x0*cos(x0) + 3.963971*x0_t*cos(x0) + 5.136864*sin(x0)*cos(x0) + -1.3526353*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  1900
# Average loss :  16.212636947631836
# expression:
# 9.1572075*x0 + 8.904328*sin(x0) + 1.7840734*cos(x0) + 3.9249258*x0**2 + -5.349615*x0*x0_t + 3.6561732*x0_t**2 + 3.1439168*x0_t*sin(x0) + 1.3987317*sin(x0)**2 + 8.1779995*x0*cos(x0) + 3.9388416*x0_t*cos(x0) + 5.140345*sin(x0)*cos(x0) + -1.3490828*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2000
# Average loss :  16.128252029418945
# expression:
# 9.160641*x0 + 8.907762*sin(x0) + 1.7805209*cos(x0) + 3.9213972*x0**2 + -5.324581*x0*x0_t + 3.6640887*x0_t**2 + 3.1690223*x0_t*sin(x0) + 1.3951793*sin(x0)**2 + 8.174566*x0*cos(x0) + 3.9137123*x0_t*cos(x0) + 5.143826*sin(x0)*cos(x0) + -1.3455304*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2100
# Average loss :  16.043867111206055
# expression:
# 9.164074*x0 + 8.911195*sin(x0) + 1.7769685*cos(x0) + 3.9178686*x0**2 + -5.299547*x0*x0_t + 3.6720042*x0_t**2 + 3.1941278*x0_t*sin(x0) + 1.3916268*sin(x0)**2 + 8.171133*x0*cos(x0) + 3.888583*x0_t*cos(x0) + 5.147307*sin(x0)*cos(x0) + -1.341978*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2200
# Average loss :  15.959490776062012
# expression:
# 9.167507*x0 + 8.914628*sin(x0) + 1.773416*cos(x0) + 3.91434*x0**2 + -5.2745132*x0*x0_t + 3.6799197*x0_t**2 + 3.2192333*x0_t*sin(x0) + 1.3880744*sin(x0)**2 + 8.1677*x0*cos(x0) + 3.8634536*x0_t*cos(x0) + 5.150788*sin(x0)*cos(x0) + -1.3384255*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2300
# Average loss :  15.87510871887207
# expression:
# 9.17094*x0 + 8.918061*sin(x0) + 1.7698636*cos(x0) + 3.9108114*x0**2 + -5.2494793*x0*x0_t + 3.6878352*x0_t**2 + 3.2443388*x0_t*sin(x0) + 1.384522*sin(x0)**2 + 8.164267*x0*cos(x0) + 3.8383243*x0_t*cos(x0) + 5.1542687*sin(x0)*cos(x0) + -1.3348731*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2400
# Average loss :  15.790727615356445
# expression:
# 9.174374*x0 + 8.9214945*sin(x0) + 1.7663112*cos(x0) + 3.9072828*x0**2 + -5.2244453*x0*x0_t + 3.6957507*x0_t**2 + 3.2694442*x0_t*sin(x0) + 1.3809695*sin(x0)**2 + 8.160833*x0*cos(x0) + 3.813195*x0_t*cos(x0) + 5.1577497*sin(x0)*cos(x0) + -1.3313206*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2500
# Average loss :  15.706342697143555
# expression:
# 9.177807*x0 + 8.924928*sin(x0) + 1.7627587*cos(x0) + 3.9037542*x0**2 + -5.1994114*x0*x0_t + 3.7036662*x0_t**2 + 3.2945497*x0_t*sin(x0) + 1.3774171*sin(x0)**2 + 8.1574*x0*cos(x0) + 3.7880657*x0_t*cos(x0) + 5.1612306*sin(x0)*cos(x0) + -1.3277682*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2600
# Average loss :  15.62195873260498
# expression:
# 9.18124*x0 + 8.928361*sin(x0) + 1.7592063*cos(x0) + 3.9002256*x0**2 + -5.1743774*x0*x0_t + 3.7115817*x0_t**2 + 3.3196552*x0_t*sin(x0) + 1.3738647*sin(x0)**2 + 8.153967*x0*cos(x0) + 3.7629364*x0_t*cos(x0) + 5.1647115*sin(x0)*cos(x0) + -1.3242158*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2700
# Average loss :  15.537574768066406
# expression:
# 9.184673*x0 + 8.931794*sin(x0) + 1.7556539*cos(x0) + 3.896697*x0**2 + -5.1493435*x0*x0_t + 3.7194972*x0_t**2 + 3.3447607*x0_t*sin(x0) + 1.3703122*sin(x0)**2 + 8.150534*x0*cos(x0) + 3.737807*x0_t*cos(x0) + 5.1681924*sin(x0)*cos(x0) + -1.3206633*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2800
# Average loss :  15.453195571899414
# expression:
# 9.188107*x0 + 8.935227*sin(x0) + 1.7521014*cos(x0) + 3.8931684*x0**2 + -5.1243095*x0*x0_t + 3.7274127*x0_t**2 + 3.3698661*x0_t*sin(x0) + 1.3667598*sin(x0)**2 + 8.1471*x0*cos(x0) + 3.7126777*x0_t*cos(x0) + 5.1716733*sin(x0)*cos(x0) + -1.3171109*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  2900
# Average loss :  15.368817329406738
# expression:
# 9.19154*x0 + 8.938661*sin(x0) + 1.748549*cos(x0) + 3.8896399*x0**2 + -5.0992756*x0*x0_t + 3.7353282*x0_t**2 + 3.3949716*x0_t*sin(x0) + 1.3632073*sin(x0)**2 + 8.143667*x0*cos(x0) + 3.6875484*x0_t*cos(x0) + 5.175154*sin(x0)*cos(x0) + -1.3135585*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3000
# Average loss :  15.284436225891113
# expression:
# 9.194973*x0 + 8.942094*sin(x0) + 1.7449965*cos(x0) + 3.8861113*x0**2 + -5.0742416*x0*x0_t + 3.7432437*x0_t**2 + 3.420077*x0_t*sin(x0) + 1.3596549*sin(x0)**2 + 8.140234*x0*cos(x0) + 3.662419*x0_t*cos(x0) + 5.178635*sin(x0)*cos(x0) + -1.310006*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3100
# Average loss :  15.200053215026855
# expression:
# 9.198406*x0 + 8.945527*sin(x0) + 1.7414441*cos(x0) + 3.8825827*x0**2 + -5.0492077*x0*x0_t + 3.7511592*x0_t**2 + 3.4451826*x0_t*sin(x0) + 1.3561025*sin(x0)**2 + 8.136801*x0*cos(x0) + 3.6372898*x0_t*cos(x0) + 5.182116*sin(x0)*cos(x0) + -1.3064536*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3200
# Average loss :  15.11567211151123
# expression:
# 9.201839*x0 + 8.94896*sin(x0) + 1.7378917*cos(x0) + 3.879054*x0**2 + -5.0241737*x0*x0_t + 3.7590747*x0_t**2 + 3.470288*x0_t*sin(x0) + 1.35255*sin(x0)**2 + 8.133368*x0*cos(x0) + 3.6121604*x0_t*cos(x0) + 5.185597*sin(x0)*cos(x0) + -1.3029011*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3300
# Average loss :  15.031291007995605
# expression:
# 9.205273*x0 + 8.952394*sin(x0) + 1.7343392*cos(x0) + 3.8755255*x0**2 + -4.99914*x0*x0_t + 3.7669902*x0_t**2 + 3.4953935*x0_t*sin(x0) + 1.3489976*sin(x0)**2 + 8.129934*x0*cos(x0) + 3.5870311*x0_t*cos(x0) + 5.189078*sin(x0)*cos(x0) + -1.2993487*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3400
# Average loss :  14.946916580200195
# expression:
# 9.208706*x0 + 8.955827*sin(x0) + 1.7307868*cos(x0) + 3.8719969*x0**2 + -4.974106*x0*x0_t + 3.7749057*x0_t**2 + 3.520499*x0_t*sin(x0) + 1.3454452*sin(x0)**2 + 8.126501*x0*cos(x0) + 3.5619018*x0_t*cos(x0) + 5.192559*sin(x0)*cos(x0) + -1.2957963*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3500
# Average loss :  14.862530708312988
# expression:
# 9.212139*x0 + 8.95926*sin(x0) + 1.7272344*cos(x0) + 3.8684683*x0**2 + -4.949072*x0*x0_t + 3.7828212*x0_t**2 + 3.5456045*x0_t*sin(x0) + 1.3418927*sin(x0)**2 + 8.123068*x0*cos(x0) + 3.5367725*x0_t*cos(x0) + 5.1960397*sin(x0)*cos(x0) + -1.2922438*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3600
# Average loss :  14.778144836425781
# expression:
# 9.215572*x0 + 8.962693*sin(x0) + 1.7236819*cos(x0) + 3.8649397*x0**2 + -4.924038*x0*x0_t + 3.7907367*x0_t**2 + 3.57071*x0_t*sin(x0) + 1.3383403*sin(x0)**2 + 8.119635*x0*cos(x0) + 3.5116432*x0_t*cos(x0) + 5.1995206*sin(x0)*cos(x0) + -1.2886914*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3700
# Average loss :  14.693765640258789
# expression:
# 9.219006*x0 + 8.966126*sin(x0) + 1.7201295*cos(x0) + 3.861411*x0**2 + -4.899004*x0*x0_t + 3.7986522*x0_t**2 + 3.5958154*x0_t*sin(x0) + 1.3347878*sin(x0)**2 + 8.116201*x0*cos(x0) + 3.4865139*x0_t*cos(x0) + 5.2030015*sin(x0)*cos(x0) + -1.285139*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3800
# Average loss :  14.609382629394531
# expression:
# 9.222439*x0 + 8.96956*sin(x0) + 1.716577*cos(x0) + 3.8578825*x0**2 + -4.87397*x0*x0_t + 3.8065677*x0_t**2 + 3.620921*x0_t*sin(x0) + 1.3312354*sin(x0)**2 + 8.112768*x0*cos(x0) + 3.4613845*x0_t*cos(x0) + 5.2064824*sin(x0)*cos(x0) + -1.2815865*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  3900
# Average loss :  14.525004386901855
# expression:
# 9.225872*x0 + 8.972993*sin(x0) + 1.7130246*cos(x0) + 3.854354*x0**2 + -4.848936*x0*x0_t + 3.8144832*x0_t**2 + 3.6460264*x0_t*sin(x0) + 1.327683*sin(x0)**2 + 8.109335*x0*cos(x0) + 3.4362552*x0_t*cos(x0) + 5.2099633*sin(x0)*cos(x0) + -1.2780341*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4000
# Average loss :  14.440620422363281
# expression:
# 9.229305*x0 + 8.976426*sin(x0) + 1.7094722*cos(x0) + 3.8508253*x0**2 + -4.823902*x0*x0_t + 3.8223987*x0_t**2 + 3.6711318*x0_t*sin(x0) + 1.3241305*sin(x0)**2 + 8.105902*x0*cos(x0) + 3.411126*x0_t*cos(x0) + 5.213444*sin(x0)*cos(x0) + -1.2744817*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4100
# Average loss :  14.356241226196289
# expression:
# 9.2327385*x0 + 8.979859*sin(x0) + 1.7059197*cos(x0) + 3.8472967*x0**2 + -4.798868*x0*x0_t + 3.8303142*x0_t**2 + 3.6962373*x0_t*sin(x0) + 1.3205781*sin(x0)**2 + 8.1024685*x0*cos(x0) + 3.3859966*x0_t*cos(x0) + 5.216925*sin(x0)*cos(x0) + -1.2709292*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4200
# Average loss :  14.271855354309082
# expression:
# 9.236172*x0 + 8.983293*sin(x0) + 1.7023673*cos(x0) + 3.8437681*x0**2 + -4.773834*x0*x0_t + 3.8382297*x0_t**2 + 3.7213428*x0_t*sin(x0) + 1.3170257*sin(x0)**2 + 8.099035*x0*cos(x0) + 3.3608673*x0_t*cos(x0) + 5.220406*sin(x0)*cos(x0) + -1.2673768*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4300
# Average loss :  14.187475204467773
# expression:
# 9.239605*x0 + 8.986726*sin(x0) + 1.6988149*cos(x0) + 3.8402395*x0**2 + -4.7488003*x0*x0_t + 3.8461452*x0_t**2 + 3.7464483*x0_t*sin(x0) + 1.3134732*sin(x0)**2 + 8.095602*x0*cos(x0) + 3.335738*x0_t*cos(x0) + 5.223887*sin(x0)*cos(x0) + -1.2638243*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4400
# Average loss :  14.103097915649414
# expression:
# 9.243038*x0 + 8.990159*sin(x0) + 1.6952624*cos(x0) + 3.836711*x0**2 + -4.7237663*x0*x0_t + 3.8540606*x0_t**2 + 3.7715538*x0_t*sin(x0) + 1.3099208*sin(x0)**2 + 8.092169*x0*cos(x0) + 3.3106086*x0_t*cos(x0) + 5.227368*sin(x0)*cos(x0) + -1.2602719*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4500
# Average loss :  14.018712997436523
# expression:
# 9.246471*x0 + 8.993592*sin(x0) + 1.69171*cos(x0) + 3.8331823*x0**2 + -4.6987324*x0*x0_t + 3.8619761*x0_t**2 + 3.7966592*x0_t*sin(x0) + 1.3063684*sin(x0)**2 + 8.088736*x0*cos(x0) + 3.2854793*x0_t*cos(x0) + 5.230849*sin(x0)*cos(x0) + -1.2567195*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4600
# Average loss :  13.934328079223633
# expression:
# 9.249905*x0 + 8.9970255*sin(x0) + 1.6881576*cos(x0) + 3.8296537*x0**2 + -4.6736984*x0*x0_t + 3.8698916*x0_t**2 + 3.8217647*x0_t*sin(x0) + 1.3028159*sin(x0)**2 + 8.085302*x0*cos(x0) + 3.26035*x0_t*cos(x0) + 5.2343297*sin(x0)*cos(x0) + -1.253167*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4700
# Average loss :  13.849952697753906
# expression:
# 9.253338*x0 + 9.000459*sin(x0) + 1.6846051*cos(x0) + 3.8261251*x0**2 + -4.6486645*x0*x0_t + 3.8778071*x0_t**2 + 3.8468702*x0_t*sin(x0) + 1.2992635*sin(x0)**2 + 8.081869*x0*cos(x0) + 3.2352207*x0_t*cos(x0) + 5.2378106*sin(x0)*cos(x0) + -1.2496146*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4800
# Average loss :  13.7655668258667
# expression:
# 9.256771*x0 + 9.003892*sin(x0) + 1.6810527*cos(x0) + 3.8225965*x0**2 + -4.6236305*x0*x0_t + 3.8857226*x0_t**2 + 3.8719757*x0_t*sin(x0) + 1.295711*sin(x0)**2 + 8.078436*x0*cos(x0) + 3.2100914*x0_t*cos(x0) + 5.2412915*sin(x0)*cos(x0) + -1.2460622*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  4900
# Average loss :  13.681195259094238
# expression:
# 9.260204*x0 + 9.007325*sin(x0) + 1.6775002*cos(x0) + 3.819068*x0**2 + -4.5985966*x0*x0_t + 3.8936381*x0_t**2 + 3.8970811*x0_t*sin(x0) + 1.2921586*sin(x0)**2 + 8.075003*x0*cos(x0) + 3.184962*x0_t*cos(x0) + 5.2447724*sin(x0)*cos(x0) + -1.2425097*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5000
# Average loss :  13.5968017578125
# expression:
# 9.263638*x0 + 9.010758*sin(x0) + 1.6739478*cos(x0) + 3.8155394*x0**2 + -4.5735626*x0*x0_t + 3.9015536*x0_t**2 + 3.9221866*x0_t*sin(x0) + 1.2886062*sin(x0)**2 + 8.071569*x0*cos(x0) + 3.1598327*x0_t*cos(x0) + 5.2482533*sin(x0)*cos(x0) + -1.2389573*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5100
# Average loss :  13.512420654296875
# expression:
# 9.267071*x0 + 9.014192*sin(x0) + 1.6703954*cos(x0) + 3.8120108*x0**2 + -4.5485287*x0*x0_t + 3.9094691*x0_t**2 + 3.947292*x0_t*sin(x0) + 1.2850537*sin(x0)**2 + 8.068136*x0*cos(x0) + 3.1347034*x0_t*cos(x0) + 5.2517343*sin(x0)*cos(x0) + -1.2354048*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5200
# Average loss :  13.428037643432617
# expression:
# 9.270504*x0 + 9.017625*sin(x0) + 1.6668429*cos(x0) + 3.8084822*x0**2 + -4.5234947*x0*x0_t + 3.9173846*x0_t**2 + 3.9723976*x0_t*sin(x0) + 1.2815013*sin(x0)**2 + 8.064703*x0*cos(x0) + 3.109574*x0_t*cos(x0) + 5.255215*sin(x0)*cos(x0) + -1.2318524*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5300
# Average loss :  13.343661308288574
# expression:
# 9.273937*x0 + 9.021058*sin(x0) + 1.6632905*cos(x0) + 3.8049536*x0**2 + -4.498461*x0*x0_t + 3.9253001*x0_t**2 + 3.997503*x0_t*sin(x0) + 1.2779489*sin(x0)**2 + 8.06127*x0*cos(x0) + 3.0844448*x0_t*cos(x0) + 5.258696*sin(x0)*cos(x0) + -1.2283*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5400
# Average loss :  13.259284973144531
# expression:
# 9.27737*x0 + 9.024491*sin(x0) + 1.6597381*cos(x0) + 3.801425*x0**2 + -4.473427*x0*x0_t + 3.9332156*x0_t**2 + 4.0225444*x0_t*sin(x0) + 1.2743964*sin(x0)**2 + 8.057837*x0*cos(x0) + 3.0593154*x0_t*cos(x0) + 5.262177*sin(x0)*cos(x0) + -1.2247475*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5500
# Average loss :  13.174921035766602
# expression:
# 9.280804*x0 + 9.027925*sin(x0) + 1.6561856*cos(x0) + 3.7978964*x0**2 + -4.448393*x0*x0_t + 3.941131*x0_t**2 + 4.0475783*x0_t*sin(x0) + 1.270844*sin(x0)**2 + 8.054403*x0*cos(x0) + 3.0341861*x0_t*cos(x0) + 5.265658*sin(x0)*cos(x0) + -1.2211951*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5600
# Average loss :  13.090551376342773
# expression:
# 9.284237*x0 + 9.031358*sin(x0) + 1.6526332*cos(x0) + 3.7943678*x0**2 + -4.423359*x0*x0_t + 3.9490466*x0_t**2 + 4.0726123*x0_t*sin(x0) + 1.2672915*sin(x0)**2 + 8.05097*x0*cos(x0) + 3.0090568*x0_t*cos(x0) + 5.269139*sin(x0)*cos(x0) + -1.2176427*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5700
# Average loss :  13.006185531616211
# expression:
# 9.28767*x0 + 9.034791*sin(x0) + 1.6490808*cos(x0) + 3.7908392*x0**2 + -4.398325*x0*x0_t + 3.956962*x0_t**2 + 4.097646*x0_t*sin(x0) + 1.2637391*sin(x0)**2 + 8.047537*x0*cos(x0) + 2.9839275*x0_t*cos(x0) + 5.2726197*sin(x0)*cos(x0) + -1.2140902*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5800
# Average loss :  12.921818733215332
# expression:
# 9.291103*x0 + 9.038224*sin(x0) + 1.6455283*cos(x0) + 3.7873106*x0**2 + -4.373291*x0*x0_t + 3.9648776*x0_t**2 + 4.12268*x0_t*sin(x0) + 1.2601867*sin(x0)**2 + 8.044104*x0*cos(x0) + 2.9587982*x0_t*cos(x0) + 5.2761006*sin(x0)*cos(x0) + -1.2105378*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  5900
# Average loss :  12.83745002746582
# expression:
# 9.294537*x0 + 9.041657*sin(x0) + 1.6419759*cos(x0) + 3.783782*x0**2 + -4.348257*x0*x0_t + 3.972793*x0_t**2 + 4.147714*x0_t*sin(x0) + 1.2566342*sin(x0)**2 + 8.04067*x0*cos(x0) + 2.9336689*x0_t*cos(x0) + 5.2795815*sin(x0)*cos(x0) + -1.2069854*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6000
# Average loss :  12.753073692321777
# expression:
# 9.29797*x0 + 9.045091*sin(x0) + 1.6384234*cos(x0) + 3.7802534*x0**2 + -4.323223*x0*x0_t + 3.9807086*x0_t**2 + 4.172748*x0_t*sin(x0) + 1.2530818*sin(x0)**2 + 8.037237*x0*cos(x0) + 2.9085395*x0_t*cos(x0) + 5.2830625*sin(x0)*cos(x0) + -1.2034329*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6100
# Average loss :  12.668708801269531
# expression:
# 9.301403*x0 + 9.048524*sin(x0) + 1.634871*cos(x0) + 3.7767248*x0**2 + -4.298189*x0*x0_t + 3.988624*x0_t**2 + 4.197782*x0_t*sin(x0) + 1.2495294*sin(x0)**2 + 8.033804*x0*cos(x0) + 2.8834102*x0_t*cos(x0) + 5.2865434*sin(x0)*cos(x0) + -1.1998805*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6200
# Average loss :  12.584339141845703
# expression:
# 9.304836*x0 + 9.051957*sin(x0) + 1.6313186*cos(x0) + 3.7731962*x0**2 + -4.273155*x0*x0_t + 3.9965396*x0_t**2 + 4.222816*x0_t*sin(x0) + 1.2459769*sin(x0)**2 + 8.030371*x0*cos(x0) + 2.858281*x0_t*cos(x0) + 5.2900243*sin(x0)*cos(x0) + -1.196328*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6300
# Average loss :  12.499968528747559
# expression:
# 9.3082695*x0 + 9.05539*sin(x0) + 1.6277661*cos(x0) + 3.7696676*x0**2 + -4.2481213*x0*x0_t + 4.0044007*x0_t**2 + 4.24785*x0_t*sin(x0) + 1.2424245*sin(x0)**2 + 8.0269375*x0*cos(x0) + 2.8331516*x0_t*cos(x0) + 5.293505*sin(x0)*cos(x0) + -1.1927756*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6400
# Average loss :  12.415599822998047
# expression:
# 9.311703*x0 + 9.058824*sin(x0) + 1.6242137*cos(x0) + 3.766139*x0**2 + -4.2230873*x0*x0_t + 4.012221*x0_t**2 + 4.272884*x0_t*sin(x0) + 1.238872*sin(x0)**2 + 8.023504*x0*cos(x0) + 2.8080223*x0_t*cos(x0) + 5.296986*sin(x0)*cos(x0) + -1.1892232*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6500
# Average loss :  12.331229209899902
# expression:
# 9.315136*x0 + 9.062257*sin(x0) + 1.6206613*cos(x0) + 3.7626104*x0**2 + -4.1980534*x0*x0_t + 4.020041*x0_t**2 + 4.297918*x0_t*sin(x0) + 1.2353196*sin(x0)**2 + 8.020071*x0*cos(x0) + 2.782893*x0_t*cos(x0) + 5.300467*sin(x0)*cos(x0) + -1.1856707*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6600
# Average loss :  12.246867179870605
# expression:
# 9.318569*x0 + 9.06569*sin(x0) + 1.6171088*cos(x0) + 3.7590818*x0**2 + -4.1730194*x0*x0_t + 4.027861*x0_t**2 + 4.322952*x0_t*sin(x0) + 1.2317672*sin(x0)**2 + 8.016638*x0*cos(x0) + 2.7577636*x0_t*cos(x0) + 5.303948*sin(x0)*cos(x0) + -1.1821183*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6700
# Average loss :  12.16249942779541
# expression:
# 9.322002*x0 + 9.069123*sin(x0) + 1.6135564*cos(x0) + 3.7555532*x0**2 + -4.1479855*x0*x0_t + 4.0356812*x0_t**2 + 4.3479857*x0_t*sin(x0) + 1.2282147*sin(x0)**2 + 8.013205*x0*cos(x0) + 2.7326343*x0_t*cos(x0) + 5.307429*sin(x0)*cos(x0) + -1.1785659*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6800
# Average loss :  12.078125953674316
# expression:
# 9.325436*x0 + 9.0725565*sin(x0) + 1.610004*cos(x0) + 3.7520247*x0**2 + -4.1229515*x0*x0_t + 4.0435014*x0_t**2 + 4.3730197*x0_t*sin(x0) + 1.2246623*sin(x0)**2 + 8.009771*x0*cos(x0) + 2.707505*x0_t*cos(x0) + 5.3109097*sin(x0)*cos(x0) + -1.1750134*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  6900
# Average loss :  11.993751525878906
# expression:
# 9.328869*x0 + 9.07599*sin(x0) + 1.6064515*cos(x0) + 3.748496*x0**2 + -4.0979176*x0*x0_t + 4.0513215*x0_t**2 + 4.3980536*x0_t*sin(x0) + 1.2211099*sin(x0)**2 + 8.006338*x0*cos(x0) + 2.6823757*x0_t*cos(x0) + 5.3143907*sin(x0)*cos(x0) + -1.171461*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7000
# Average loss :  11.90938663482666
# expression:
# 9.332302*x0 + 9.079423*sin(x0) + 1.6028991*cos(x0) + 3.7449675*x0**2 + -4.0728836*x0*x0_t + 4.0591416*x0_t**2 + 4.4230876*x0_t*sin(x0) + 1.2175574*sin(x0)**2 + 8.002905*x0*cos(x0) + 2.6572464*x0_t*cos(x0) + 5.3178716*sin(x0)*cos(x0) + -1.1679085*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7100
# Average loss :  11.825019836425781
# expression:
# 9.335735*x0 + 9.082856*sin(x0) + 1.5993466*cos(x0) + 3.7414389*x0**2 + -4.0478497*x0*x0_t + 4.066962*x0_t**2 + 4.4481215*x0_t*sin(x0) + 1.214005*sin(x0)**2 + 7.9994717*x0*cos(x0) + 2.632117*x0_t*cos(x0) + 5.3213525*sin(x0)*cos(x0) + -1.1643561*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7200
# Average loss :  11.74064826965332
# expression:
# 9.339169*x0 + 9.086289*sin(x0) + 1.5957942*cos(x0) + 3.7379103*x0**2 + -4.0228157*x0*x0_t + 4.074782*x0_t**2 + 4.4731555*x0_t*sin(x0) + 1.2104526*sin(x0)**2 + 7.9960384*x0*cos(x0) + 2.6069877*x0_t*cos(x0) + 5.3248334*sin(x0)*cos(x0) + -1.1608037*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7300
# Average loss :  11.656257629394531
# expression:
# 9.342602*x0 + 9.089723*sin(x0) + 1.5922418*cos(x0) + 3.7343817*x0**2 + -3.9977732*x0*x0_t + 4.082602*x0_t**2 + 4.4981894*x0_t*sin(x0) + 1.2069001*sin(x0)**2 + 7.992605*x0*cos(x0) + 2.5818584*x0_t*cos(x0) + 5.3283143*sin(x0)*cos(x0) + -1.1572512*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7400
# Average loss :  11.571619033813477
# expression:
# 9.346035*x0 + 9.093156*sin(x0) + 1.5886893*cos(x0) + 3.730853*x0**2 + -3.9726439*x0*x0_t + 4.090422*x0_t**2 + 4.5232234*x0_t*sin(x0) + 1.2033477*sin(x0)**2 + 7.989172*x0*cos(x0) + 2.556729*x0_t*cos(x0) + 5.331795*sin(x0)*cos(x0) + -1.1536988*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7500
# Average loss :  11.486983299255371
# expression:
# 9.349468*x0 + 9.096589*sin(x0) + 1.5851369*cos(x0) + 3.7273245*x0**2 + -3.9475145*x0*x0_t + 4.0982423*x0_t**2 + 4.5482574*x0_t*sin(x0) + 1.1997952*sin(x0)**2 + 7.9857388*x0*cos(x0) + 2.5315998*x0_t*cos(x0) + 5.335276*sin(x0)*cos(x0) + -1.1501464*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7600
# Average loss :  11.402347564697266
# expression:
# 9.352901*x0 + 9.100022*sin(x0) + 1.5815845*cos(x0) + 3.723796*x0**2 + -3.9223852*x0*x0_t + 4.1060624*x0_t**2 + 4.5732913*x0_t*sin(x0) + 1.1962428*sin(x0)**2 + 7.9823055*x0*cos(x0) + 2.5064704*x0_t*cos(x0) + 5.338757*sin(x0)*cos(x0) + -1.1465939*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7700
# Average loss :  11.317713737487793
# expression:
# 9.356335*x0 + 9.103456*sin(x0) + 1.578032*cos(x0) + 3.7202673*x0**2 + -3.897256*x0*x0_t + 4.1138825*x0_t**2 + 4.5983253*x0_t*sin(x0) + 1.1926904*sin(x0)**2 + 7.9788723*x0*cos(x0) + 2.4813411*x0_t*cos(x0) + 5.342238*sin(x0)*cos(x0) + -1.1430415*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7800
# Average loss :  11.233078956604004
# expression:
# 9.359768*x0 + 9.106889*sin(x0) + 1.5744796*cos(x0) + 3.7167387*x0**2 + -3.8721266*x0*x0_t + 4.1217027*x0_t**2 + 4.623359*x0_t*sin(x0) + 1.1891379*sin(x0)**2 + 7.975439*x0*cos(x0) + 2.4562118*x0_t*cos(x0) + 5.345719*sin(x0)*cos(x0) + -1.139489*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  7900
# Average loss :  11.1484375
# expression:
# 9.363201*x0 + 9.110322*sin(x0) + 1.5709271*cos(x0) + 3.71321*x0**2 + -3.8469973*x0*x0_t + 4.129523*x0_t**2 + 4.648393*x0_t*sin(x0) + 1.1855855*sin(x0)**2 + 7.972006*x0*cos(x0) + 2.4310825*x0_t*cos(x0) + 5.3492*sin(x0)*cos(x0) + -1.1359366*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8000
# Average loss :  11.063799858093262
# expression:
# 9.366634*x0 + 9.113755*sin(x0) + 1.5673747*cos(x0) + 3.7096815*x0**2 + -3.821868*x0*x0_t + 4.137343*x0_t**2 + 4.673427*x0_t*sin(x0) + 1.1820331*sin(x0)**2 + 7.9685726*x0*cos(x0) + 2.4059532*x0_t*cos(x0) + 5.3526807*sin(x0)*cos(x0) + -1.1323842*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8100
# Average loss :  10.979330062866211
# expression:
# 9.370293*x0 + 9.1174135*sin(x0) + 1.5635831*cos(x0) + 3.7058716*x0**2 + -3.7967668*x0*x0_t + 4.145163*x0_t**2 + 4.698405*x0_t*sin(x0) + 1.1782415*sin(x0)**2 + 7.9649143*x0*cos(x0) + 2.380852*x0_t*cos(x0) + 5.3563867*sin(x0)*cos(x0) + -1.1285926*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8200
# Average loss :  10.894960403442383
# expression:
# 9.374107*x0 + 9.121228*sin(x0) + 1.5596254*cos(x0) + 3.7018661*x0**2 + -3.7716851*x0*x0_t + 4.152983*x0_t**2 + 4.7233434*x0_t*sin(x0) + 1.1742837*sin(x0)**2 + 7.9610996*x0*cos(x0) + 2.3557703*x0_t*cos(x0) + 5.360249*sin(x0)*cos(x0) + -1.1246349*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8300
# Average loss :  10.81059741973877
# expression:
# 9.377922*x0 + 9.125043*sin(x0) + 1.5556676*cos(x0) + 3.6978607*x0**2 + -3.7466035*x0*x0_t + 4.1608033*x0_t**2 + 4.748282*x0_t*sin(x0) + 1.170326*sin(x0)**2 + 7.957285*x0*cos(x0) + 2.3306887*x0_t*cos(x0) + 5.3641114*sin(x0)*cos(x0) + -1.1206771*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8400
# Average loss :  10.726235389709473
# expression:
# 9.381737*x0 + 9.128858*sin(x0) + 1.5517099*cos(x0) + 3.6938553*x0**2 + -3.7215219*x0*x0_t + 4.1686234*x0_t**2 + 4.7732205*x0_t*sin(x0) + 1.1663682*sin(x0)**2 + 7.95347*x0*cos(x0) + 2.305607*x0_t*cos(x0) + 5.367974*sin(x0)*cos(x0) + -1.1167194*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8500
# Average loss :  10.641871452331543
# expression:
# 9.385551*x0 + 9.132672*sin(x0) + 1.5477521*cos(x0) + 3.6898499*x0**2 + -3.6964402*x0*x0_t + 4.1764436*x0_t**2 + 4.798159*x0_t*sin(x0) + 1.1624105*sin(x0)**2 + 7.9496555*x0*cos(x0) + 2.2805254*x0_t*cos(x0) + 5.371836*sin(x0)*cos(x0) + -1.1127616*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8600
# Average loss :  10.55750846862793
# expression:
# 9.389366*x0 + 9.136487*sin(x0) + 1.5437944*cos(x0) + 3.6858444*x0**2 + -3.6713586*x0*x0_t + 4.1842637*x0_t**2 + 4.8230977*x0_t*sin(x0) + 1.1584527*sin(x0)**2 + 7.945841*x0*cos(x0) + 2.2554438*x0_t*cos(x0) + 5.3756986*sin(x0)*cos(x0) + -1.1088039*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8700
# Average loss :  10.47314167022705
# expression:
# 9.393181*x0 + 9.140302*sin(x0) + 1.5398366*cos(x0) + 3.681839*x0**2 + -3.646277*x0*x0_t + 4.192084*x0_t**2 + 4.8480363*x0_t*sin(x0) + 1.154495*sin(x0)**2 + 7.942026*x0*cos(x0) + 2.2303622*x0_t*cos(x0) + 5.379561*sin(x0)*cos(x0) + -1.1048461*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8800
# Average loss :  10.388772964477539
# expression:
# 9.396996*x0 + 9.144116*sin(x0) + 1.5358789*cos(x0) + 3.6778336*x0**2 + -3.6211953*x0*x0_t + 4.199904*x0_t**2 + 4.872975*x0_t*sin(x0) + 1.1505373*sin(x0)**2 + 7.9382114*x0*cos(x0) + 2.2052805*x0_t*cos(x0) + 5.3834233*sin(x0)*cos(x0) + -1.1008884*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  8900
# Average loss :  10.304414749145508
# expression:
# 9.40081*x0 + 9.147931*sin(x0) + 1.5319211*cos(x0) + 3.6738281*x0**2 + -3.5961137*x0*x0_t + 4.207724*x0_t**2 + 4.8979135*x0_t*sin(x0) + 1.1465795*sin(x0)**2 + 7.9343967*x0*cos(x0) + 2.180199*x0_t*cos(x0) + 5.3872857*sin(x0)*cos(x0) + -1.0969306*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9000
# Average loss :  10.220048904418945
# expression:
# 9.404625*x0 + 9.151746*sin(x0) + 1.5279634*cos(x0) + 3.6698227*x0**2 + -3.571032*x0*x0_t + 4.215544*x0_t**2 + 4.922852*x0_t*sin(x0) + 1.1426218*sin(x0)**2 + 7.930582*x0*cos(x0) + 2.1551173*x0_t*cos(x0) + 5.391148*sin(x0)*cos(x0) + -1.0929729*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9100
# Average loss :  10.1356840133667
# expression:
# 9.40844*x0 + 9.1555605*sin(x0) + 1.5240057*cos(x0) + 3.6658173*x0**2 + -3.5459504*x0*x0_t + 4.2233644*x0_t**2 + 4.9477906*x0_t*sin(x0) + 1.138664*sin(x0)**2 + 7.9267673*x0*cos(x0) + 2.1300356*x0_t*cos(x0) + 5.3950105*sin(x0)*cos(x0) + -1.0890151*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9200
# Average loss :  10.051318168640137
# expression:
# 9.412254*x0 + 9.159375*sin(x0) + 1.5200479*cos(x0) + 3.6618118*x0**2 + -3.5208688*x0*x0_t + 4.2311845*x0_t**2 + 4.972729*x0_t*sin(x0) + 1.1347063*sin(x0)**2 + 7.9229527*x0*cos(x0) + 2.104954*x0_t*cos(x0) + 5.398873*sin(x0)*cos(x0) + -1.0850574*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9300
# Average loss :  9.966952323913574
# expression:
# 9.416069*x0 + 9.16319*sin(x0) + 1.5160902*cos(x0) + 3.6578064*x0**2 + -3.4957871*x0*x0_t + 4.2390046*x0_t**2 + 4.997668*x0_t*sin(x0) + 1.1307485*sin(x0)**2 + 7.919138*x0*cos(x0) + 2.0798724*x0_t*cos(x0) + 5.402735*sin(x0)*cos(x0) + -1.0810996*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9400
# Average loss :  9.882591247558594
# expression:
# 9.419884*x0 + 9.167005*sin(x0) + 1.5121324*cos(x0) + 3.653801*x0**2 + -3.4707055*x0*x0_t + 4.2468247*x0_t**2 + 5.0226064*x0_t*sin(x0) + 1.1267908*sin(x0)**2 + 7.9153233*x0*cos(x0) + 2.0547907*x0_t*cos(x0) + 5.4065976*sin(x0)*cos(x0) + -1.0771419*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9500
# Average loss :  9.798225402832031
# expression:
# 9.423698*x0 + 9.170819*sin(x0) + 1.5081747*cos(x0) + 3.6497955*x0**2 + -3.4456239*x0*x0_t + 4.254645*x0_t**2 + 5.047545*x0_t*sin(x0) + 1.122833*sin(x0)**2 + 7.9115086*x0*cos(x0) + 2.029709*x0_t*cos(x0) + 5.41046*sin(x0)*cos(x0) + -1.0731841*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9600
# Average loss :  9.713860511779785
# expression:
# 9.427513*x0 + 9.174634*sin(x0) + 1.5042169*cos(x0) + 3.64579*x0**2 + -3.4205422*x0*x0_t + 4.262465*x0_t**2 + 5.0724835*x0_t*sin(x0) + 1.1188753*sin(x0)**2 + 7.907694*x0*cos(x0) + 2.0046275*x0_t*cos(x0) + 5.4143224*sin(x0)*cos(x0) + -1.0692264*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9700
# Average loss :  9.629483222961426
# expression:
# 9.431328*x0 + 9.178449*sin(x0) + 1.5002592*cos(x0) + 3.6417847*x0**2 + -3.3954606*x0*x0_t + 4.270285*x0_t**2 + 5.097422*x0_t*sin(x0) + 1.1149175*sin(x0)**2 + 7.903879*x0*cos(x0) + 1.9795069*x0_t*cos(x0) + 5.4181848*sin(x0)*cos(x0) + -1.0652686*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9800
# Average loss :  9.545101165771484
# expression:
# 9.4351425*x0 + 9.182263*sin(x0) + 1.4963014*cos(x0) + 3.6377792*x0**2 + -3.370379*x0*x0_t + 4.2781053*x0_t**2 + 5.1223607*x0_t*sin(x0) + 1.1109598*sin(x0)**2 + 7.9000645*x0*cos(x0) + 1.9543775*x0_t*cos(x0) + 5.422047*sin(x0)*cos(x0) + -1.0613109*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  9900
# Average loss :  9.46072006225586
# expression:
# 9.438957*x0 + 9.186078*sin(x0) + 1.4923437*cos(x0) + 3.6337738*x0**2 + -3.3452973*x0*x0_t + 4.2859254*x0_t**2 + 5.1472993*x0_t*sin(x0) + 1.107002*sin(x0)**2 + 7.89625*x0*cos(x0) + 1.9292482*x0_t*cos(x0) + 5.4259095*sin(x0)*cos(x0) + -1.0573531*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10000
# Average loss :  9.376333236694336
# expression:
# 9.442772*x0 + 9.189893*sin(x0) + 1.4883859*cos(x0) + 3.6297684*x0**2 + -3.3202157*x0*x0_t + 4.2937455*x0_t**2 + 5.172238*x0_t*sin(x0) + 1.1030443*sin(x0)**2 + 7.892435*x0*cos(x0) + 1.9041189*x0_t*cos(x0) + 5.429772*sin(x0)*cos(x0) + -1.0533954*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10100
# Average loss :  9.291952133178711
# expression:
# 9.446587*x0 + 9.193707*sin(x0) + 1.4844282*cos(x0) + 3.625763*x0**2 + -3.295134*x0*x0_t + 4.3015656*x0_t**2 + 5.1971765*x0_t*sin(x0) + 1.0990865*sin(x0)**2 + 7.8886204*x0*cos(x0) + 1.8789896*x0_t*cos(x0) + 5.4336343*sin(x0)*cos(x0) + -1.0494376*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10200
# Average loss :  9.20757007598877
# expression:
# 9.450401*x0 + 9.197522*sin(x0) + 1.4804704*cos(x0) + 3.6217575*x0**2 + -3.2700524*x0*x0_t + 4.309386*x0_t**2 + 5.222115*x0_t*sin(x0) + 1.0951288*sin(x0)**2 + 7.8848057*x0*cos(x0) + 1.8538603*x0_t*cos(x0) + 5.4374967*sin(x0)*cos(x0) + -1.0454799*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10300
# Average loss :  9.123188018798828
# expression:
# 9.454216*x0 + 9.201337*sin(x0) + 1.4765127*cos(x0) + 3.617752*x0**2 + -3.2449708*x0*x0_t + 4.317206*x0_t**2 + 5.2470536*x0_t*sin(x0) + 1.091171*sin(x0)**2 + 7.880991*x0*cos(x0) + 1.828731*x0_t*cos(x0) + 5.441359*sin(x0)*cos(x0) + -1.0415221*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10400
# Average loss :  9.038803100585938
# expression:
# 9.458031*x0 + 9.205152*sin(x0) + 1.4725549*cos(x0) + 3.6137466*x0**2 + -3.2198892*x0*x0_t + 4.325026*x0_t**2 + 5.271992*x0_t*sin(x0) + 1.0872133*sin(x0)**2 + 7.8771763*x0*cos(x0) + 1.8036016*x0_t*cos(x0) + 5.4452214*sin(x0)*cos(x0) + -1.0375644*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10500
# Average loss :  8.954422950744629
# expression:
# 9.461845*x0 + 9.208966*sin(x0) + 1.4685972*cos(x0) + 3.6097412*x0**2 + -3.1948075*x0*x0_t + 4.332846*x0_t**2 + 5.296931*x0_t*sin(x0) + 1.0832555*sin(x0)**2 + 7.8733616*x0*cos(x0) + 1.7784723*x0_t*cos(x0) + 5.449084*sin(x0)*cos(x0) + -1.0336066*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10600
# Average loss :  8.870038986206055
# expression:
# 9.46566*x0 + 9.212781*sin(x0) + 1.4646394*cos(x0) + 3.6057358*x0**2 + -3.169726*x0*x0_t + 4.3406663*x0_t**2 + 5.3218694*x0_t*sin(x0) + 1.0792978*sin(x0)**2 + 7.869547*x0*cos(x0) + 1.753343*x0_t*cos(x0) + 5.452946*sin(x0)*cos(x0) + -1.0296489*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10700
# Average loss :  8.785656929016113
# expression:
# 9.469475*x0 + 9.216596*sin(x0) + 1.4606817*cos(x0) + 3.6017303*x0**2 + -3.1446443*x0*x0_t + 4.3484864*x0_t**2 + 5.346808*x0_t*sin(x0) + 1.07534*sin(x0)**2 + 7.865732*x0*cos(x0) + 1.7282137*x0_t*cos(x0) + 5.4568086*sin(x0)*cos(x0) + -1.0256912*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10800
# Average loss :  8.701272964477539
# expression:
# 9.4732895*x0 + 9.22041*sin(x0) + 1.4567239*cos(x0) + 3.597725*x0**2 + -3.1195626*x0*x0_t + 4.3563066*x0_t**2 + 5.3717465*x0_t*sin(x0) + 1.0713823*sin(x0)**2 + 7.8619175*x0*cos(x0) + 1.7030843*x0_t*cos(x0) + 5.460671*sin(x0)*cos(x0) + -1.0217334*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  10900
# Average loss :  8.616890907287598
# expression:
# 9.477104*x0 + 9.224225*sin(x0) + 1.4527662*cos(x0) + 3.5937195*x0**2 + -3.094481*x0*x0_t + 4.3641267*x0_t**2 + 5.396685*x0_t*sin(x0) + 1.0674245*sin(x0)**2 + 7.858103*x0*cos(x0) + 1.677955*x0_t*cos(x0) + 5.4645333*sin(x0)*cos(x0) + -1.0177757*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11000
# Average loss :  8.532514572143555
# expression:
# 9.480919*x0 + 9.22804*sin(x0) + 1.4488084*cos(x0) + 3.589714*x0**2 + -3.0693994*x0*x0_t + 4.371947*x0_t**2 + 5.4216237*x0_t*sin(x0) + 1.0634668*sin(x0)**2 + 7.854288*x0*cos(x0) + 1.6528257*x0_t*cos(x0) + 5.4683957*sin(x0)*cos(x0) + -1.0138179*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11100
# Average loss :  8.448124885559082
# expression:
# 9.484734*x0 + 9.231854*sin(x0) + 1.4448507*cos(x0) + 3.5857086*x0**2 + -3.0443177*x0*x0_t + 4.379767*x0_t**2 + 5.4465623*x0_t*sin(x0) + 1.059509*sin(x0)**2 + 7.8504734*x0*cos(x0) + 1.6276964*x0_t*cos(x0) + 5.472258*sin(x0)*cos(x0) + -1.0098602*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11200
# Average loss :  8.363744735717773
# expression:
# 9.488548*x0 + 9.235669*sin(x0) + 1.4408929*cos(x0) + 3.5817032*x0**2 + -3.019236*x0*x0_t + 4.387587*x0_t**2 + 5.471501*x0_t*sin(x0) + 1.0555513*sin(x0)**2 + 7.8466587*x0*cos(x0) + 1.6025671*x0_t*cos(x0) + 5.4761205*sin(x0)*cos(x0) + -1.0059024*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11300
# Average loss :  8.279356956481934
# expression:
# 9.492363*x0 + 9.239484*sin(x0) + 1.4369352*cos(x0) + 3.5776978*x0**2 + -2.9941545*x0*x0_t + 4.395407*x0_t**2 + 5.4964395*x0_t*sin(x0) + 1.0515935*sin(x0)**2 + 7.842844*x0*cos(x0) + 1.5774378*x0_t*cos(x0) + 5.479983*sin(x0)*cos(x0) + -1.0019447*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11400
# Average loss :  8.194977760314941
# expression:
# 9.496178*x0 + 9.243299*sin(x0) + 1.4329774*cos(x0) + 3.5736923*x0**2 + -2.9690728*x0*x0_t + 4.4032273*x0_t**2 + 5.521378*x0_t*sin(x0) + 1.0476358*sin(x0)**2 + 7.8390293*x0*cos(x0) + 1.5523084*x0_t*cos(x0) + 5.483845*sin(x0)*cos(x0) + -0.9979869*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11500
# Average loss :  8.110597610473633
# expression:
# 9.499992*x0 + 9.247113*sin(x0) + 1.4290197*cos(x0) + 3.569687*x0**2 + -2.9439912*x0*x0_t + 4.4110475*x0_t**2 + 5.5463166*x0_t*sin(x0) + 1.043678*sin(x0)**2 + 7.8352146*x0*cos(x0) + 1.5271791*x0_t*cos(x0) + 5.4877076*sin(x0)*cos(x0) + -0.99402916*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11600
# Average loss :  8.026215553283691
# expression:
# 9.503807*x0 + 9.250928*sin(x0) + 1.425062*cos(x0) + 3.5656815*x0**2 + -2.9189095*x0*x0_t + 4.4188676*x0_t**2 + 5.571255*x0_t*sin(x0) + 1.0397203*sin(x0)**2 + 7.8314*x0*cos(x0) + 1.5020498*x0_t*cos(x0) + 5.49157*sin(x0)*cos(x0) + -0.9900714*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11700
# Average loss :  7.941832065582275
# expression:
# 9.507622*x0 + 9.254743*sin(x0) + 1.4211042*cos(x0) + 3.561676*x0**2 + -2.893828*x0*x0_t + 4.4266877*x0_t**2 + 5.596194*x0_t*sin(x0) + 1.0357625*sin(x0)**2 + 7.827585*x0*cos(x0) + 1.4769205*x0_t*cos(x0) + 5.4954324*sin(x0)*cos(x0) + -0.98611367*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11800
# Average loss :  7.857450008392334
# expression:
# 9.511436*x0 + 9.258557*sin(x0) + 1.4171464*cos(x0) + 3.5576706*x0**2 + -2.8687463*x0*x0_t + 4.434508*x0_t**2 + 5.6211324*x0_t*sin(x0) + 1.0318048*sin(x0)**2 + 7.8237705*x0*cos(x0) + 1.4517912*x0_t*cos(x0) + 5.4992948*sin(x0)*cos(x0) + -0.9821559*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  11900
# Average loss :  7.773067474365234
# expression:
# 9.515251*x0 + 9.262372*sin(x0) + 1.4131887*cos(x0) + 3.5536652*x0**2 + -2.8436646*x0*x0_t + 4.442328*x0_t**2 + 5.646071*x0_t*sin(x0) + 1.027847*sin(x0)**2 + 7.819956*x0*cos(x0) + 1.4266618*x0_t*cos(x0) + 5.503157*sin(x0)*cos(x0) + -0.9781982*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12000
# Average loss :  7.688685417175293
# expression:
# 9.519066*x0 + 9.266187*sin(x0) + 1.409231*cos(x0) + 3.5496597*x0**2 + -2.818583*x0*x0_t + 4.450148*x0_t**2 + 5.6710095*x0_t*sin(x0) + 1.0238893*sin(x0)**2 + 7.816141*x0*cos(x0) + 1.4015325*x0_t*cos(x0) + 5.5070195*sin(x0)*cos(x0) + -0.9742404*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12100
# Average loss :  7.6042985916137695
# expression:
# 9.522881*x0 + 9.270001*sin(x0) + 1.4052732*cos(x0) + 3.5456543*x0**2 + -2.7935014*x0*x0_t + 4.457968*x0_t**2 + 5.695948*x0_t*sin(x0) + 1.0199316*sin(x0)**2 + 7.8123264*x0*cos(x0) + 1.3764032*x0_t*cos(x0) + 5.510882*sin(x0)*cos(x0) + -0.9702827*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12200
# Average loss :  7.519917964935303
# expression:
# 9.526695*x0 + 9.273816*sin(x0) + 1.4013155*cos(x0) + 3.5416489*x0**2 + -2.7684197*x0*x0_t + 4.4657884*x0_t**2 + 5.7208867*x0_t*sin(x0) + 1.0159738*sin(x0)**2 + 7.8085117*x0*cos(x0) + 1.3512739*x0_t*cos(x0) + 5.5147443*sin(x0)*cos(x0) + -0.9663249*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12300
# Average loss :  7.435535430908203
# expression:
# 9.53051*x0 + 9.277631*sin(x0) + 1.3973577*cos(x0) + 3.5376434*x0**2 + -2.743338*x0*x0_t + 4.4736085*x0_t**2 + 5.7458253*x0_t*sin(x0) + 1.012016*sin(x0)**2 + 7.804697*x0*cos(x0) + 1.3261446*x0_t*cos(x0) + 5.5186067*sin(x0)*cos(x0) + -0.9623672*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12400
# Average loss :  7.3511528968811035
# expression:
# 9.534325*x0 + 9.2814455*sin(x0) + 1.3934*cos(x0) + 3.533638*x0**2 + -2.7182565*x0*x0_t + 4.4814286*x0_t**2 + 5.770764*x0_t*sin(x0) + 1.0080583*sin(x0)**2 + 7.8008823*x0*cos(x0) + 1.3010153*x0_t*cos(x0) + 5.522469*sin(x0)*cos(x0) + -0.9584094*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12500
# Average loss :  7.2667694091796875
# expression:
# 9.538139*x0 + 9.28526*sin(x0) + 1.3894422*cos(x0) + 3.5296326*x0**2 + -2.6931748*x0*x0_t + 4.4892488*x0_t**2 + 5.7957025*x0_t*sin(x0) + 1.0041006*sin(x0)**2 + 7.7970676*x0*cos(x0) + 1.2758859*x0_t*cos(x0) + 5.5263314*sin(x0)*cos(x0) + -0.9544517*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12600
# Average loss :  7.1823883056640625
# expression:
# 9.541954*x0 + 9.289075*sin(x0) + 1.3854845*cos(x0) + 3.5256271*x0**2 + -2.6680932*x0*x0_t + 4.497069*x0_t**2 + 5.820641*x0_t*sin(x0) + 1.0001428*sin(x0)**2 + 7.793253*x0*cos(x0) + 1.2507566*x0_t*cos(x0) + 5.530194*sin(x0)*cos(x0) + -0.95049393*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12700
# Average loss :  7.098008632659912
# expression:
# 9.545769*x0 + 9.29289*sin(x0) + 1.3815267*cos(x0) + 3.5216217*x0**2 + -2.6430116*x0*x0_t + 4.504889*x0_t**2 + 5.8455796*x0_t*sin(x0) + 0.99618495*sin(x0)**2 + 7.7894382*x0*cos(x0) + 1.2256273*x0_t*cos(x0) + 5.534056*sin(x0)*cos(x0) + -0.9465362*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12800
# Average loss :  7.013619899749756
# expression:
# 9.549583*x0 + 9.296704*sin(x0) + 1.377569*cos(x0) + 3.5176163*x0**2 + -2.61793*x0*x0_t + 4.512709*x0_t**2 + 5.870518*x0_t*sin(x0) + 0.9922272*sin(x0)**2 + 7.7856236*x0*cos(x0) + 1.200498*x0_t*cos(x0) + 5.5379186*sin(x0)*cos(x0) + -0.94257843*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  12900
# Average loss :  6.929239749908447
# expression:
# 9.553398*x0 + 9.300519*sin(x0) + 1.3736112*cos(x0) + 3.5136108*x0**2 + -2.5928483*x0*x0_t + 4.5205293*x0_t**2 + 5.895457*x0_t*sin(x0) + 0.98826945*sin(x0)**2 + 7.781809*x0*cos(x0) + 1.1753687*x0_t*cos(x0) + 5.541781*sin(x0)*cos(x0) + -0.9386207*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  13000
# Average loss :  6.844855308532715
# expression:
# 9.557213*x0 + 9.304334*sin(x0) + 1.3696535*cos(x0) + 3.5096054*x0**2 + -2.5677667*x0*x0_t + 4.5283494*x0_t**2 + 5.9203954*x0_t*sin(x0) + 0.9843117*sin(x0)**2 + 7.777994*x0*cos(x0) + 1.1502393*x0_t*cos(x0) + 5.5456433*sin(x0)*cos(x0) + -0.93466294*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  13100
# Average loss :  6.760476112365723
# expression:
# 9.561028*x0 + 9.308148*sin(x0) + 1.3656957*cos(x0) + 3.5056*x0**2 + -2.542685*x0*x0_t + 4.5361695*x0_t**2 + 5.945334*x0_t*sin(x0) + 0.98035395*sin(x0)**2 + 7.7741795*x0*cos(x0) + 1.12511*x0_t*cos(x0) + 5.5495057*sin(x0)*cos(x0) + -0.9307052*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  13200
# Average loss :  6.67609167098999
# expression:
# 9.564842*x0 + 9.311963*sin(x0) + 1.361738*cos(x0) + 3.5015945*x0**2 + -2.5176034*x0*x0_t + 4.5439897*x0_t**2 + 5.9702725*x0_t*sin(x0) + 0.9763962*sin(x0)**2 + 7.7703648*x0*cos(x0) + 1.0999807*x0_t*cos(x0) + 5.553368*sin(x0)*cos(x0) + -0.92674744*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  13300
# Average loss :  6.591709136962891
# expression:
# 9.568657*x0 + 9.315778*sin(x0) + 1.3577802*cos(x0) + 3.497589*x0**2 + -2.4925218*x0*x0_t + 4.55181*x0_t**2 + 5.995211*x0_t*sin(x0) + 0.97243845*sin(x0)**2 + 7.76655*x0*cos(x0) + 1.0748514*x0_t*cos(x0) + 5.5572305*sin(x0)*cos(x0) + -0.9227897*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  13400
# Average loss :  6.507328033447266
# expression:
# 9.572472*x0 + 9.319592*sin(x0) + 1.3538225*cos(x0) + 3.4935837*x0**2 + -2.4674401*x0*x0_t + 4.55963*x0_t**2 + 6.0201497*x0_t*sin(x0) + 0.9684807*sin(x0)**2 + 7.7627354*x0*cos(x0) + 1.0497221*x0_t*cos(x0) + 5.561093*sin(x0)*cos(x0) + -0.91883194*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  13500
# Average loss :  6.422945499420166
# expression:
# 9.576286*x0 + 9.323407*sin(x0) + 1.3498647*cos(x0) + 3.4895782*x0**2 + -2.4423585*x0*x0_t + 4.56745*x0_t**2 + 6.0450883*x0_t*sin(x0) + 0.96452296*sin(x0)**2 + 7.7589207*x0*cos(x0) + 1.0245928*x0_t*cos(x0) + 5.564955*sin(x0)*cos(x0) + -0.9148742*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  13600
# Average loss :  6.33856201171875
# expression:
# 9.580101*x0 + 9.327222*sin(x0) + 1.345907*cos(x0) + 3.4855728*x0**2 + -2.4172769*x0*x0_t + 4.57527*x0_t**2 + 6.070027*x0_t*sin(x0) + 0.9605652*sin(x0)**2 + 7.755106*x0*cos(x0) + 0.99946404*x0_t*cos(x0) + 5.5688176*sin(x0)*cos(x0) + -0.91091645*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  13700
# Average loss :  6.2541913986206055
# expression:
# 9.583916*x0 + 9.331037*sin(x0) + 1.3419492*cos(x0) + 3.4815674*x0**2 + -2.3921952*x0*x0_t + 4.5830903*x0_t**2 + 6.0949655*x0_t*sin(x0) + 0.95660746*sin(x0)**2 + 7.7512913*x0*cos(x0) + 0.9743705*x0_t*cos(x0) + 5.57268*sin(x0)*cos(x0) + -0.9069587*cos(x0)**2 +
# number of candidates:  12
#
#
# Epoch:  13800
# Average loss :  6.169824123382568
# expression:
# ...
# expression:
# 11.762915*x0 + 11.5100355*sin(x0) + 1.2757907*x0**2 + -0.4902986*x0*x0_t + 8.006957*x0_t*sin(x0) + 5.5779147*x0*cos(x0) + 7.7509823*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  93400
# Average loss :  0.0017814148450270295
# expression:
# 11.762829*x0 + 11.50995*sin(x0) + 1.2757776*x0**2 + -0.49029028*x0*x0_t + 8.006934*x0_t*sin(x0) + 5.577964*x0*cos(x0) + 7.750933*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  93500
# Average loss :  0.0017788844415917993
# expression:
# 11.762727*x0 + 11.509848*sin(x0) + 1.2757748*x0**2 + -0.4902924*x0*x0_t + 8.006899*x0_t*sin(x0) + 5.578026*x0*cos(x0) + 7.750871*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  93600
# Average loss :  0.0017802489455789328
# expression:
# 11.762659*x0 + 11.50978*sin(x0) + 1.275741*x0**2 + -0.4902896*x0*x0_t + 8.006871*x0_t*sin(x0) + 5.5780554*x0*cos(x0) + 7.7508416*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  93700
# Average loss :  0.0017842806410044432
# expression:
# 11.762595*x0 + 11.509716*sin(x0) + 1.2757078*x0**2 + -0.49028692*x0*x0_t + 8.006844*x0_t*sin(x0) + 5.578084*x0*cos(x0) + 7.750813*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  93800
# Average loss :  0.0017793163424357772
# expression:
# 11.762499*x0 + 11.50962*sin(x0) + 1.2757062*x0**2 + -0.4902892*x0*x0_t + 8.006808*x0_t*sin(x0) + 5.5781446*x0*cos(x0) + 7.7507524*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  93900
# Average loss :  0.0017828593263402581
# expression:
# 11.762437*x0 + 11.509558*sin(x0) + 1.2756734*x0**2 + -0.4902866*x0*x0_t + 8.006781*x0_t*sin(x0) + 5.5781727*x0*cos(x0) + 7.7507243*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94000
# Average loss :  0.001781427301466465
# expression:
# 11.762353*x0 + 11.509474*sin(x0) + 1.2756606*x0**2 + -0.49027833*x0*x0_t + 8.006758*x0_t*sin(x0) + 5.5782213*x0*cos(x0) + 7.7506757*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94100
# Average loss :  0.0017793005099520087
# expression:
# 11.762257*x0 + 11.5093775*sin(x0) + 1.275659*x0**2 + -0.49028063*x0*x0_t + 8.006722*x0_t*sin(x0) + 5.578282*x0*cos(x0) + 7.750615*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94200
# Average loss :  0.001780583173967898
# expression:
# 11.762195*x0 + 11.5093155*sin(x0) + 1.2756262*x0**2 + -0.490278*x0*x0_t + 8.006695*x0_t*sin(x0) + 5.57831*x0*cos(x0) + 7.750587*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94300
# Average loss :  0.0017842997331172228
# expression:
# 11.762127*x0 + 11.509248*sin(x0) + 1.2755923*x0**2 + -0.4902752*x0*x0_t + 8.006667*x0_t*sin(x0) + 5.5783396*x0*cos(x0) + 7.7505574*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94400
# Average loss :  0.0017796175088733435
# expression:
# 11.762031*x0 + 11.509151*sin(x0) + 1.2755907*x0**2 + -0.4902775*x0*x0_t + 8.006632*x0_t*sin(x0) + 5.5784*x0*cos(x0) + 7.750497*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94500
# Average loss :  0.0017827259143814445
# expression:
# 11.761967*x0 + 11.509088*sin(x0) + 1.2755575*x0**2 + -0.49027482*x0*x0_t + 8.006604*x0_t*sin(x0) + 5.5784287*x0*cos(x0) + 7.7504683*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94600
# Average loss :  0.0017816011095419526
# expression:
# 11.761874*x0 + 11.508995*sin(x0) + 1.2755566*x0**2 + -0.49027723*x0*x0_t + 8.006569*x0_t*sin(x0) + 5.5784883*x0*cos(x0) + 7.7504086*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94700
# Average loss :  0.0017793088918551803
# expression:
# 11.761792*x0 + 11.508913*sin(x0) + 1.2755442*x0**2 + -0.49026904*x0*x0_t + 8.006546*x0_t*sin(x0) + 5.5785365*x0*cos(x0) + 7.7503605*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94800
# Average loss :  0.0017805283423513174
# expression:
# 11.761723*x0 + 11.508843*sin(x0) + 1.27551*x0**2 + -0.49026617*x0*x0_t + 8.006518*x0_t*sin(x0) + 5.5785666*x0*cos(x0) + 7.7503304*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  94900
# Average loss :  0.0017842433881014585
# expression:
# 11.761654*x0 + 11.508775*sin(x0) + 1.2754893*x0**2 + -0.49027428*x0*x0_t + 8.006478*x0_t*sin(x0) + 5.578605*x0*cos(x0) + 7.750292*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95000
# Average loss :  0.0017794184386730194
# expression:
# 11.761564*x0 + 11.508685*sin(x0) + 1.2754755*x0**2 + -0.49026585*x0*x0_t + 8.006455*x0_t*sin(x0) + 5.5786552*x0*cos(x0) + 7.7502418*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95100
# Average loss :  0.001783481566235423
# expression:
# 11.761497*x0 + 11.508617*sin(x0) + 1.2754416*x0**2 + -0.49026304*x0*x0_t + 8.006428*x0_t*sin(x0) + 5.578685*x0*cos(x0) + 7.750212*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95200
# Average loss :  0.0017820557113736868
# expression:
# 11.7614*x0 + 11.508521*sin(x0) + 1.27544*x0**2 + -0.49026534*x0*x0_t + 8.0063925*x0_t*sin(x0) + 5.5787454*x0*cos(x0) + 7.7501516*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95300
# Average loss :  0.0017822782974690199
# expression:
# 11.761329*x0 + 11.50845*sin(x0) + 1.2754054*x0**2 + -0.49026242*x0*x0_t + 8.006365*x0_t*sin(x0) + 5.578776*x0*cos(x0) + 7.750121*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95400
# Average loss :  0.001781312981620431
# expression:
# 11.761237*x0 + 11.508358*sin(x0) + 1.2753912*x0**2 + -0.49025393*x0*x0_t + 8.006342*x0_t*sin(x0) + 5.5788264*x0*cos(x0) + 7.7500706*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95500
# Average loss :  0.0017846401315182447
# expression:
# 11.761161*x0 + 11.508282*sin(x0) + 1.2753692*x0**2 + -0.4902618*x0*x0_t + 8.006302*x0_t*sin(x0) + 5.578867*x0*cos(x0) + 7.75003*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95600
# Average loss :  0.0017800095956772566
# expression:
# 11.761069*x0 + 11.50819*sin(x0) + 1.275355*x0**2 + -0.4902533*x0*x0_t + 8.006279*x0_t*sin(x0) + 5.5789175*x0*cos(x0) + 7.7499795*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95700
# Average loss :  0.0017838331405073404
# expression:
# 11.760998*x0 + 11.508119*sin(x0) + 1.2753204*x0**2 + -0.49025038*x0*x0_t + 8.006251*x0_t*sin(x0) + 5.578948*x0*cos(x0) + 7.749949*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95800
# Average loss :  0.001779045327566564
# expression:
# 11.7609*x0 + 11.50802*sin(x0) + 1.2753184*x0**2 + -0.4902526*x0*x0_t + 8.006216*x0_t*sin(x0) + 5.579009*x0*cos(x0) + 7.749888*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  95900
# Average loss :  0.0017827661940827966
# expression:
# 11.760832*x0 + 11.507953*sin(x0) + 1.2752845*x0**2 + -0.4902498*x0*x0_t + 8.006188*x0_t*sin(x0) + 5.5790386*x0*cos(x0) + 7.7498584*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96000
# Average loss :  0.0017816973850131035
# expression:
# 11.76074*x0 + 11.507861*sin(x0) + 1.2752703*x0**2 + -0.49024132*x0*x0_t + 8.0061655*x0_t*sin(x0) + 5.579089*x0*cos(x0) + 7.749808*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96100
# Average loss :  0.0017791378777474165
# expression:
# 11.760646*x0 + 11.507767*sin(x0) + 1.275269*x0**2 + -0.49024367*x0*x0_t + 8.00613*x0_t*sin(x0) + 5.5791492*x0*cos(x0) + 7.7497478*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96200
# Average loss :  0.0017802920192480087
# expression:
# 11.760582*x0 + 11.507703*sin(x0) + 1.2752359*x0**2 + -0.490241*x0*x0_t + 8.006103*x0_t*sin(x0) + 5.579178*x0*cos(x0) + 7.749719*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96300
# Average loss :  0.0017843286041170359
# expression:
# 11.760514*x0 + 11.507635*sin(x0) + 1.275202*x0**2 + -0.4902382*x0*x0_t + 8.006075*x0_t*sin(x0) + 5.5792074*x0*cos(x0) + 7.7496896*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96400
# Average loss :  0.0017790535930544138
# expression:
# 11.760422*x0 + 11.507543*sin(x0) + 1.2752011*x0**2 + -0.4902406*x0*x0_t + 8.00604*x0_t*sin(x0) + 5.579267*x0*cos(x0) + 7.74963*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96500
# Average loss :  0.0017829518765211105
# expression:
# 11.760352*x0 + 11.507473*sin(x0) + 1.2751669*x0**2 + -0.49023774*x0*x0_t + 8.006012*x0_t*sin(x0) + 5.579297*x0*cos(x0) + 7.7496*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96600
# Average loss :  0.001781806699000299
# expression:
# 11.760262*x0 + 11.507382*sin(x0) + 1.2751663*x0**2 + -0.49024022*x0*x0_t + 8.005977*x0_t*sin(x0) + 5.579356*x0*cos(x0) + 7.749541*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96700
# Average loss :  0.001781855127774179
# expression:
# 11.760198*x0 + 11.5073185*sin(x0) + 1.2751331*x0**2 + -0.49023753*x0*x0_t + 8.005949*x0_t*sin(x0) + 5.579385*x0*cos(x0) + 7.749512*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96800
# Average loss :  0.001780863618478179
# expression:
# 11.760106*x0 + 11.507227*sin(x0) + 1.275119*x0**2 + -0.49022904*x0*x0_t + 8.005926*x0_t*sin(x0) + 5.5794353*x0*cos(x0) + 7.7494617*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  96900
# Average loss :  0.0017843253444880247
# expression:
# 11.760034*x0 + 11.507154*sin(x0) + 1.2750976*x0**2 + -0.49023703*x0*x0_t + 8.005886*x0_t*sin(x0) + 5.579475*x0*cos(x0) + 7.749422*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97000
# Average loss :  0.0017798652406781912
# expression:
# 11.759944*x0 + 11.507065*sin(x0) + 1.2750838*x0**2 + -0.4902286*x0*x0_t + 8.005863*x0_t*sin(x0) + 5.579525*x0*cos(x0) + 7.749372*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97100
# Average loss :  0.0017831672448664904
# expression:
# 11.75988*x0 + 11.507001*sin(x0) + 1.2750506*x0**2 + -0.4902259*x0*x0_t + 8.005836*x0_t*sin(x0) + 5.5795536*x0*cos(x0) + 7.7493434*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97200
# Average loss :  0.001782055594958365
# expression:
# 11.759789*x0 + 11.50691*sin(x0) + 1.27505*x0**2 + -0.49022838*x0*x0_t + 8.0058*x0_t*sin(x0) + 5.5796127*x0*cos(x0) + 7.7492843*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97300
# Average loss :  0.0017820049542933702
# expression:
# 11.7597275*x0 + 11.506848*sin(x0) + 1.2750173*x0**2 + -0.49022576*x0*x0_t + 8.005773*x0_t*sin(x0) + 5.579641*x0*cos(x0) + 7.749256*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97400
# Average loss :  0.0017811624566093087
# expression:
# 11.759642*x0 + 11.5067625*sin(x0) + 1.2750041*x0**2 + -0.49021745*x0*x0_t + 8.00575*x0_t*sin(x0) + 5.57969*x0*cos(x0) + 7.749207*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97500
# Average loss :  0.0017848085844889283
# expression:
# 11.759563*x0 + 11.506684*sin(x0) + 1.2749817*x0**2 + -0.49022526*x0*x0_t + 8.00571*x0_t*sin(x0) + 5.579731*x0*cos(x0) + 7.749166*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97600
# Average loss :  0.00177976512350142
# expression:
# 11.759474*x0 + 11.506595*sin(x0) + 1.2749679*x0**2 + -0.49021682*x0*x0_t + 8.005687*x0_t*sin(x0) + 5.579781*x0*cos(x0) + 7.749116*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97700
# Average loss :  0.0017837561899796128
# expression:
# 11.759402*x0 + 11.506523*sin(x0) + 1.2749333*x0**2 + -0.4902139*x0*x0_t + 8.005659*x0_t*sin(x0) + 5.5798116*x0*cos(x0) + 7.7490854*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97800
# Average loss :  0.001782500883564353
# expression:
# 11.759306*x0 + 11.506427*sin(x0) + 1.2749317*x0**2 + -0.4902162*x0*x0_t + 8.005624*x0_t*sin(x0) + 5.579872*x0*cos(x0) + 7.749025*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  97900
# Average loss :  0.0017828494310379028
# expression:
# 11.759236*x0 + 11.506357*sin(x0) + 1.2748975*x0**2 + -0.49021333*x0*x0_t + 8.005596*x0_t*sin(x0) + 5.579902*x0*cos(x0) + 7.748995*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98000
# Average loss :  0.0017815700266510248
# expression:
# 11.759143*x0 + 11.506264*sin(x0) + 1.2748829*x0**2 + -0.49020478*x0*x0_t + 8.005573*x0_t*sin(x0) + 5.579953*x0*cos(x0) + 7.748944*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98100
# Average loss :  0.0017814214807003736
# expression:
# 11.759065*x0 + 11.506186*sin(x0) + 1.2748605*x0**2 + -0.4902126*x0*x0_t + 8.005533*x0_t*sin(x0) + 5.579994*x0*cos(x0) + 7.748903*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98200
# Average loss :  0.001780367107130587
# expression:
# 11.758983*x0 + 11.5061035*sin(x0) + 1.2748481*x0**2 + -0.4902044*x0*x0_t + 8.00551*x0_t*sin(x0) + 5.5800424*x0*cos(x0) + 7.7488546*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98300
# Average loss :  0.0017837744671851397
# expression:
# 11.758904*x0 + 11.506025*sin(x0) + 1.2748257*x0**2 + -0.4902122*x0*x0_t + 8.00547*x0_t*sin(x0) + 5.5800834*x0*cos(x0) + 7.7488136*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98400
# Average loss :  0.0017789201810956001
# expression:
# 11.758817*x0 + 11.505938*sin(x0) + 1.2748122*x0**2 + -0.49020383*x0*x0_t + 8.005447*x0_t*sin(x0) + 5.580133*x0*cos(x0) + 7.748764*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98500
# Average loss :  0.0017829474527388811
# expression:
# 11.758747*x0 + 11.505868*sin(x0) + 1.274778*x0**2 + -0.49020097*x0*x0_t + 8.00542*x0_t*sin(x0) + 5.580163*x0*cos(x0) + 7.748734*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98600
# Average loss :  0.0017815263709053397
# expression:
# 11.758645*x0 + 11.505766*sin(x0) + 1.2747753*x0**2 + -0.49020308*x0*x0_t + 8.005384*x0_t*sin(x0) + 5.580225*x0*cos(x0) + 7.748672*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98700
# Average loss :  0.0017819323111325502
# expression:
# 11.758575*x0 + 11.505696*sin(x0) + 1.274741*x0**2 + -0.49020022*x0*x0_t + 8.005357*x0_t*sin(x0) + 5.580255*x0*cos(x0) + 7.748642*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98800
# Average loss :  0.001780729042366147
# expression:
# 11.75849*x0 + 11.50561*sin(x0) + 1.274728*x0**2 + -0.4901919*x0*x0_t + 8.005334*x0_t*sin(x0) + 5.580304*x0*cos(x0) + 7.748593*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  98900
# Average loss :  0.0017845159163698554
# expression:
# 11.758413*x0 + 11.505534*sin(x0) + 1.2747059*x0**2 + -0.49019977*x0*x0_t + 8.005294*x0_t*sin(x0) + 5.5803447*x0*cos(x0) + 7.7485523*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99000
# Average loss :  0.0017797134350985289
# expression:
# 11.758324*x0 + 11.505445*sin(x0) + 1.274692*x0**2 + -0.49019134*x0*x0_t + 8.005271*x0_t*sin(x0) + 5.5803947*x0*cos(x0) + 7.7485023*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99100
# Average loss :  0.00178354955278337
# expression:
# 11.758258*x0 + 11.505379*sin(x0) + 1.2746586*x0**2 + -0.4901886*x0*x0_t + 8.005243*x0_t*sin(x0) + 5.580424*x0*cos(x0) + 7.748473*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99200
# Average loss :  0.0017820678185671568
# expression:
# 11.758165*x0 + 11.505286*sin(x0) + 1.2746576*x0**2 + -0.490191*x0*x0_t + 8.005208*x0_t*sin(x0) + 5.5804834*x0*cos(x0) + 7.7484136*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99300
# Average loss :  0.0017825933173298836
# expression:
# 11.7581*x0 + 11.50522*sin(x0) + 1.2746241*x0**2 + -0.49018827*x0*x0_t + 8.00518*x0_t*sin(x0) + 5.5805125*x0*cos(x0) + 7.7483845*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99400
# Average loss :  0.0017809050623327494
# expression:
# 11.758014*x0 + 11.505135*sin(x0) + 1.274611*x0**2 + -0.49017996*x0*x0_t + 8.005157*x0_t*sin(x0) + 5.5805616*x0*cos(x0) + 7.7483354*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99500
# Average loss :  0.0017811611760407686
# expression:
# 11.757934*x0 + 11.505054*sin(x0) + 1.2745882*x0**2 + -0.4901877*x0*x0_t + 8.005117*x0_t*sin(x0) + 5.580603*x0*cos(x0) + 7.748294*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99600
# Average loss :  0.0017798531334847212
# expression:
# 11.757846*x0 + 11.504967*sin(x0) + 1.2745748*x0**2 + -0.49017933*x0*x0_t + 8.005095*x0_t*sin(x0) + 5.5806527*x0*cos(x0) + 7.7482443*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99700
# Average loss :  0.0017839393112808466
# expression:
# 11.757778*x0 + 11.504899*sin(x0) + 1.2745409*x0**2 + -0.49017653*x0*x0_t + 8.005067*x0_t*sin(x0) + 5.5806823*x0*cos(x0) + 7.7482147*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99800
# Average loss :  0.00177902786526829
# expression:
# 11.75768*x0 + 11.504801*sin(x0) + 1.2745389*x0**2 + -0.49017876*x0*x0_t + 8.005032*x0_t*sin(x0) + 5.5807433*x0*cos(x0) + 7.7481537*sin(x0)*cos(x0) +
# number of candidates:  7
#
#
# Epoch:  99900
# Average loss :  0.0017825609538704157
# expression:
# 11.757612*x0 + 11.504733*sin(x0) + 1.274505*x0**2 + -0.49017596*x0*x0_t + 8.005004*x0_t*sin(x0) + 5.580773*x0*cos(x0) + 7.748124*sin(x0)*cos(x0) +
# number of candidates:  7

# %%
one = x.copy()
one = one[:2500]
second = dx*cos(x)
second = second[:2500]
coef = coef.to(device)
#coef = coef.cpu()
result = torch.matmul(coef,[one,second])
result = result.cpu()
plt.plot(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       5 coef = coef.to(device)
#       6 #coef = coef.cpu()
# ----> 7 result = torch.matmul(coef,[one,second])
#       8 result = result.cpu()
#       9 plt.plot(result)
#
# TypeError: matmul(): argument 'other' (position 2) must be Tensor, not list

# %%
plt.plot(loss_history)

# %%
coef_path = os.path.join(PATH,'coef.csv')
expr_path = os.path.join(PATH,'expr.csv')
with open(coef_path, 'w') as f:
    writer = csv.writer(f)
    writer.writerow(coef)
with open(expr_path, 'w') as f:
    writer = csv.writer(f)
    writer.writerow(expr)
